# %%
import pickle

# %%
summary_df = pickle.load(open('../models/summary.pkl','rb'))

# %%
summary_df
# Out:
#               Variable Name         Max         Min
# 0               radius_mean    28.11000    6.981000
# 1              texture_mean    39.28000    9.710000
# 2            perimeter_mean   188.50000   43.790000
# 3                 area_mean  2501.00000  143.500000
# 4           smoothness_mean     0.16340    0.052630
# 5          compactness_mean     0.34540    0.019380
# 6            concavity_mean     0.42680    0.000000
# 7       concave points_mean     0.20120    0.000000
# 8             symmetry_mean     0.30400    0.106000
# 9    fractal_dimension_mean     0.09744    0.049960
# 10                radius_se     2.87300    0.111500
# 11               texture_se     4.88500    0.360200
# 12             perimeter_se    21.98000    0.757000
# 13                  area_se   542.20000    6.802000
# 14            smoothness_se     0.03113    0.001713
# 15           compactness_se     0.13540    0.002252
# 16             concavity_se     0.39600    0.000000
# ...

# %%
feature_names = [
        "Radius Mean",
        "Texture Mean",
        "Perimeter Mean",
        "Area Mean",
        "Smoothness Mean",
        "Compactness Mean",
        "Concavity Mean",
        "Concave Points Mean",
        "Symmetry Mean",
        "Fractal Dimension Mean",
        "Radius SE",
        "Texture SE",
        "Perimeter SE",
        "Area SE",
        "Smoothness SE",
        "Compactness SE",
        "Concavity SE",
        "Concave Points SE",
        "Symmetry SE",
        "Fractal Dimension SE",
        "Radius Worst",
        "Texture Worst",
        "Perimeter Worst",
        "Area Worst",
        "Smoothness Worst",
        "Compactness Worst",
        "Concavity Worst",
        "Concave Points Worst",
        "Symmetry Worst",
        "Fractal Dimension Worst"
    ]

# %%
summary_df['Name'] = feature_names

# %%
summary_df
# Out:
#               Variable Name         Max         Min                     Name
# 0               radius_mean    28.11000    6.981000              Radius Mean
# 1              texture_mean    39.28000    9.710000             Texture Mean
# 2            perimeter_mean   188.50000   43.790000           Perimeter Mean
# 3                 area_mean  2501.00000  143.500000                Area Mean
# 4           smoothness_mean     0.16340    0.052630          Smoothness Mean
# 5          compactness_mean     0.34540    0.019380         Compactness Mean
# 6            concavity_mean     0.42680    0.000000           Concavity Mean
# 7       concave points_mean     0.20120    0.000000      Concave Points Mean
# 8             symmetry_mean     0.30400    0.106000            Symmetry Mean
# 9    fractal_dimension_mean     0.09744    0.049960   Fractal Dimension Mean
# 10                radius_se     2.87300    0.111500                Radius SE
# ...

# %%
for j,i in summary_df.iterrows():
    print(i["Name"])
# Out:
# Radius Mean
# Texture Mean
# Perimeter Mean
# Area Mean
# Smoothness Mean
# Compactness Mean
# Concavity Mean
# Concave Points Mean
# Symmetry Mean
# Fractal Dimension Mean
# Radius SE
# Texture SE
# Perimeter SE
# Area SE
# Smoothness SE
# Compactness SE
# Concavity SE
# Concave Points SE
# Symmetry SE
# Fractal Dimension SE
# Radius Worst
# Texture Worst
# Perimeter Worst
# Area Worst
# Smoothness Worst
# Compactness Worst
# Concavity Worst
# Concave Points Worst
# Symmetry Worst
# Fractal Dimension Worst

# %%
import pandas as pd

# %%
data = pd.read_csv("../data/data.csv")

# %%
df = data.iloc[:5,2:-1]

# %%
df.to_csv('out.csv', index=False)

# %%
out = pd.read_csv("../data/out.csv")

# %%
out.iloc[0].values.astype(float)
# Out:
# array([1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#        3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#        8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#        3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#        1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01])

# %%
# Sample dictionary with keys as column names and values as desired values
input_dict = {
    'Radius Mean': 15.0,
    'Texture Mean': 20.0,
    'Perimeter Mean': 100.0,
    'Area Mean': 800.0,
    'Smoothness Mean': 0.1,
    'Compactness Mean': 0.2,
    'Concavity Mean': 0.15,
    'Concave Points Mean': 0.08,
    'Symmetry Mean': 0.2,
    'Fractal Dimension Mean': 0.05
}

# %%
scaler = pickle.load(open('../models/scaler.pkl','rb'))

# %%
input_df = pd.DataFrame([input_dict])
scaled_data = scaler.transform(input_df)
print("Scaled Data:", scaled_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 input_df = pd.DataFrame([input_dict])
# ----> 2 scaled_data = scaler.transform(input_df)
#       3 print("Scaled Data:", scaled_data)
#
# File E:\PROJECTS - AI\ml-breast-cancer-prediction\env\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# ...
